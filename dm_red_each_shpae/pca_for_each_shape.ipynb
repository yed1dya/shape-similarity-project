# %%
# Cell 1: Import libraries and mount Google Drive
from google.colab import drive
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Path to the main folder containing shape folders
main_folder_path = '/content/drive/MyDrive/shapes'
output_folder_path = os.path.join(main_folder_path, "pca_plots")  # Folder to save PCA plots

# Create the output folder if it doesn't exist
os.makedirs(output_folder_path, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 2: Function to load images from a folder
def load_images_from_folder(folder_path):
    """
    Load all images from a given folder as flattened grayscale arrays.
    Separates original image from child drawings.
    Keeps original 200x200 resolution.
    """
    data = []
    labels = []
    original_data = None
    original_label = None

    for file_name in os.listdir(folder_path):
        if file_name.endswith(".png"):  # Process only PNG files
            file_path = os.path.join(folder_path, file_name)
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            if image is not None:
                # Verify the image is 200x200, if not, skip it
                if image.shape == (200, 200):
                    flattened_image = image.flatten()  # Flatten the 200x200 image (40,000 features)
                    label = file_name.split(".")[0]  # Use filename without extension as label

                    # Check if this is the original image
                    if file_name.startswith("original"):
                        original_data = flattened_image
                        original_label = label
                    else:
                        data.append(flattened_image)
                        labels.append(label)
                else:
                    print(f"Warning: {file_name} is not 200x200 (shape: {image.shape}), skipping...")

    return np.array(data), labels, original_data, original_label

# %%
# Cell 3: Function to apply PCA
def apply_pca(data, n_components=2):
    """
    Apply PCA for dimensionality reduction.
    """
    pca = PCA(n_components=n_components)
    reduced_data = pca.fit_transform(data)
    return reduced_data

# %%
# Cell 4: Functions to create visualizations and calculate distances
def calculate_distances(reduced_data, original_reduced, labels):
    """
    Calculate Euclidean distances from original image to all child drawings in PCA space.
    """
    distances = []
    for i, point in enumerate(reduced_data):
        distance = euclidean_distances([original_reduced], [point])[0][0]
        distances.append({
            'child_id': labels[i],
            'distance': distance,
            'pca_x': point[0],
            'pca_y': point[1]
        })
    return distances

def save_pca_plot_with_distances(reduced_data, labels, original_reduced, original_label,
                                output_file_path, shape_name, distances_df):
    """
    Save a PCA plot with the original image highlighted and distance information.
    """
    plt.figure(figsize=(14, 10))

    # Plot child drawings
    scatter = plt.scatter(reduced_data[:, 0], reduced_data[:, 1],
                         alpha=0.7, c=distances_df['distance'],
                         cmap='viridis_r', s=60)

    # Plot original image in bold/larger
    plt.scatter(original_reduced[0], original_reduced[1],
               color='red', s=200, marker='*',
               edgecolors='black', linewidth=2,
               label=f'Original ({original_label})')

    # Add labels for child drawings
    for i, label in enumerate(labels):
        plt.annotate(label, (reduced_data[i, 0], reduced_data[i, 1]),
                    xytext=(5, 5), textcoords='offset points',
                    fontsize=8, alpha=0.8)

    # Add colorbar for distances
    cbar = plt.colorbar(scatter)
    cbar.set_label('Distance from Original', rotation=270, labelpad=15)

    plt.title(f"PCA Analysis for {shape_name} - Distances from Original")
    plt.xlabel("PCA Dimension 1")
    plt.ylabel("PCA Dimension 2")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved PCA plot to {output_file_path}")

def load_and_display_images(folder_path, child_ids, title, output_file_path, distances_df):
    """
    Load and display images in a montage with scores and child IDs.
    """
    fig, axes = plt.subplots(2, 5, figsize=(20, 8))
    fig.suptitle(title, fontsize=16, fontweight='bold')

    for i, child_id in enumerate(child_ids):
        row = i // 5
        col = i % 5

        # Load the image
        image_path = os.path.join(folder_path, f"{child_id}.png")
        if os.path.exists(image_path):
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            axes[row, col].imshow(image, cmap='gray')
        else:
            # If image not found, show empty plot
            axes[row, col].text(0.5, 0.5, 'Image\nNot Found',
                              ha='center', va='center', transform=axes[row, col].transAxes)

        # Get the distance score for this child
        distance = distances_df[distances_df['child_id'] == child_id]['distance'].iloc[0]

        # Set title with child ID and score
        axes[row, col].set_title(f'ID: {child_id}\nScore: {distance:.3f}',
                                fontsize=12, fontweight='bold')
        axes[row, col].axis('off')

    plt.tight_layout()
    plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved image montage to {output_file_path}")

def save_top_bottom_images_montage(distances_df, folder_path, output_file_path, shape_name):
    """
    Save image montages showing top 5 and bottom 5 drawings with their scores.
    """
    # Get top 5 (closest) and bottom 5 (farthest)
    top_5 = distances_df.nsmallest(5, 'distance')
    bottom_5 = distances_df.nlargest(5, 'distance')

    # Combine top 5 and bottom 5
    combined_ids = list(top_5['child_id']) + list(bottom_5['child_id'])

    # Create the montage
    title = f'{shape_name} - Top 5 Closest (Row 1) and Top 5 Farthest (Row 2)'
    load_and_display_images(folder_path, combined_ids, title, output_file_path, distances_df)

def save_original_image_display(folder_path, original_label, output_file_path, shape_name):
    """
    Save a display of the original image for reference.
    """
    original_path = os.path.join(folder_path, f"{original_label}.png")

    if os.path.exists(original_path):
        original_image = cv2.imread(original_path, cv2.IMREAD_GRAYSCALE)

        plt.figure(figsize=(8, 8))
        plt.imshow(original_image, cmap='gray')
        plt.title(f'Original Reference Image - {shape_name}', fontsize=16, fontweight='bold')
        plt.axis('off')
        plt.tight_layout()
        plt.savefig(output_file_path, dpi=300, bbox_inches='tight')
        plt.close()
        print(f"Saved original image display to {output_file_path}")
    else:
        print(f"Original image not found at {original_path}")

# %%
# Cell 5: Function to process all folders with distance analysis
def process_folders_for_pca(main_folder_path, output_folder_path):
    """
    Process each shape folder, apply PCA, calculate distances, and save the plots and scores.
    """
    all_results = {}

    for shape_folder in os.listdir(main_folder_path):
        shape_folder_path = os.path.join(main_folder_path, shape_folder)

        # Check if it's a valid shape folder
        if os.path.isdir(shape_folder_path) and shape_folder.startswith("shape"):
            print(f"\nProcessing {shape_folder}...")

            # Load images and separate original from child drawings
            data, labels, original_data, original_label = load_images_from_folder(shape_folder_path)

            if data.shape[0] == 0:
                print(f"No child drawing images found in {shape_folder}. Skipping.")
                continue

            if original_data is None:
                print(f"No original image found in {shape_folder}. Skipping.")
                continue

            print(f"Loaded {data.shape[0]} child drawings and 1 original image for {shape_folder}.")

            # Combine all data for PCA (original + child drawings)
            all_data = np.vstack([original_data.reshape(1, -1), data])

            # Apply PCA to all images
            reduced_data_all = apply_pca(all_data)

            # Separate original and child drawings in reduced space
            original_reduced = reduced_data_all[0]
            child_reduced = reduced_data_all[1:]

            # Calculate distances from original to each child drawing
            distances_info = calculate_distances(child_reduced, original_reduced, labels)
            distances_df = pd.DataFrame(distances_info)
            distances_df = distances_df.sort_values('distance')

            # Save results
            all_results[shape_folder] = distances_df

            # 1. Save PCA plot with distances visualization
            pca_plot_path = os.path.join(output_folder_path, f"{shape_folder}_pca_distances.png")
            save_pca_plot_with_distances(child_reduced, labels, original_reduced,
                                       original_label, pca_plot_path, shape_folder, distances_df)

            # 2. Save original image for reference
            original_display_path = os.path.join(output_folder_path, f"{shape_folder}_original_reference.png")
            save_original_image_display(shape_folder_path, original_label, original_display_path, shape_folder)

            # 3. Save top/bottom images montage (instead of bar chart)
            images_montage_path = os.path.join(output_folder_path, f"{shape_folder}_top_bottom_images.png")
            save_top_bottom_images_montage(distances_df, shape_folder_path, images_montage_path, shape_folder)

            # 4. Save scores list to CSV
            scores_csv_path = os.path.join(output_folder_path, f"{shape_folder}_all_scores.csv")
            distances_df.to_csv(scores_csv_path, index=False)
            print(f"Saved all scores to {scores_csv_path}")

            # Display summary statistics
            print(f"Distance statistics for {shape_folder}:")
            print(f"  Mean distance: {distances_df['distance'].mean():.3f}")
            print(f"  Std deviation: {distances_df['distance'].std():.3f}")
            print(f"  Min distance: {distances_df['distance'].min():.3f} (Child ID: {distances_df.iloc[0]['child_id']})")
            print(f"  Max distance: {distances_df['distance'].max():.3f} (Child ID: {distances_df.iloc[-1]['child_id']})")

    return all_results

# %%
# Cell 6: Main function and execution
def main():
    # Process each shape folder and generate PCA plots with distance analysis
    results = process_folders_for_pca(main_folder_path, output_folder_path)

    # Print summary of all processed shapes
    print(f"\n{'='*50}")
    print("SUMMARY OF ALL PROCESSED SHAPES")
    print(f"{'='*50}")

    for shape_name, distances_df in results.items():
        print(f"\n{shape_name}:")
        print(f"  Total drawings: {len(distances_df)}")
        print(f"  Mean distance from original: {distances_df['distance'].mean():.3f}")
        print(f"  Best match (closest): {distances_df.iloc[0]['child_id']} (distance: {distances_df.iloc[0]['distance']:.3f})")
        print(f"  Worst match (farthest): {distances_df.iloc[-1]['child_id']} (distance: {distances_df.iloc[-1]['distance']:.3f})")

    return results

# Run the main function
results = main()
# Out:
# Processing shape5...
# Loaded 893 child drawings and 1 original image for shape5.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape5_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape5_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape5_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape5_all_scores.csv
# Distance statistics for shape5:
#   Mean distance: 7232.383
#   Std deviation: 1116.416
#   Min distance: 3129.789 (Child ID: 11058)
#   Max distance: 9325.961 (Child ID: 10353)
#
# Processing shape3...
# Loaded 897 child drawings and 1 original image for shape3.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape3_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape3_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape3_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape3_all_scores.csv
# Distance statistics for shape3:
#   Mean distance: 7165.484
#   Std deviation: 1250.403
#   Min distance: 2889.581 (Child ID: 10367)
#   Max distance: 10278.177 (Child ID: 10996)
#
# Processing shape4...
# Loaded 895 child drawings and 1 original image for shape4.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape4_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape4_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape4_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape4_all_scores.csv
# Distance statistics for shape4:
#   Mean distance: 6809.838
#   Std deviation: 998.313
#   Min distance: 2798.157 (Child ID: 7637)
#   Max distance: 8919.910 (Child ID: 10879)
#
# Processing shape6...
# Loaded 889 child drawings and 1 original image for shape6.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape6_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape6_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape6_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape6_all_scores.csv
# Distance statistics for shape6:
#   Mean distance: 6746.418
#   Std deviation: 1072.227
#   Min distance: 3337.622 (Child ID: 10308)
#   Max distance: 8796.106 (Child ID: 10090)
#
# Processing shape7...
# Loaded 893 child drawings and 1 original image for shape7.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape7_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape7_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape7_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape7_all_scores.csv
# Distance statistics for shape7:
#   Mean distance: 1491.864
#   Std deviation: 459.891
#   Min distance: 72.664 (Child ID: 10729)
#   Max distance: 6196.660 (Child ID: 10706)
#
# Processing shape2...
# Loaded 900 child drawings and 1 original image for shape2.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape2_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape2_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape2_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape2_all_scores.csv
# Distance statistics for shape2:
#   Mean distance: 8129.395
#   Std deviation: 1055.717
#   Min distance: 1884.322 (Child ID: 11024)
#   Max distance: 14262.520 (Child ID: 10653)
#
# Processing shape16...
# Loaded 896 child drawings and 1 original image for shape16.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape16_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape16_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape16_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape16_all_scores.csv
# Distance statistics for shape16:
#   Mean distance: 6919.515
#   Std deviation: 670.606
#   Min distance: 3800.943 (Child ID: 10815)
#   Max distance: 8277.591 (Child ID: 10021)
#
# Processing shape17...
# Loaded 893 child drawings and 1 original image for shape17.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape17_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape17_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape17_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape17_all_scores.csv
# Distance statistics for shape17:
#   Mean distance: 7125.450
#   Std deviation: 702.164
#   Min distance: 4280.648 (Child ID: 7557)
#   Max distance: 8835.445 (Child ID: 10308)
#
# Processing shape14...
# Loaded 890 child drawings and 1 original image for shape14.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape14_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape14_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape14_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape14_all_scores.csv
# Distance statistics for shape14:
#   Mean distance: 2581.520
#   Std deviation: 1134.952
#   Min distance: 365.346 (Child ID: 10149)
#   Max distance: 11562.565 (Child ID: 11013)
#
# Processing shape18...
# Loaded 876 child drawings and 1 original image for shape18.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape18_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape18_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape18_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape18_all_scores.csv
# Distance statistics for shape18:
#   Mean distance: 4303.232
#   Std deviation: 1130.127
#   Min distance: 384.508 (Child ID: 10522)
#   Max distance: 11703.122 (Child ID: 10643)
#
# Processing shape9...
# Loaded 898 child drawings and 1 original image for shape9.
# Saved PCA plot to /content/drive/MyDrive/shapes/pca_plots/shape9_pca_distances.png
# Saved original image display to /content/drive/MyDrive/shapes/pca_plots/shape9_original_reference.png
# Saved image montage to /content/drive/MyDrive/shapes/pca_plots/shape9_top_bottom_images.png
# Saved all scores to /content/drive/MyDrive/shapes/pca_plots/shape9_all_scores.csv
# Distance statistics for shape9:
#   Mean distance: 8447.039
#   Std deviation: 770.974
#   Min distance: 4406.916 (Child ID: 10005)
#   Max distance: 10042.571 (Child ID: 10952)
#
# ==================================================
# SUMMARY OF ALL PROCESSED SHAPES
# ==================================================
#
# shape5:
#   Total drawings: 893
#   Mean distance from original: 7232.383
#   Best match (closest): 11058 (distance: 3129.789)
#   Worst match (farthest): 10353 (distance: 9325.961)
#
# shape3:
#   Total drawings: 897
#   Mean distance from original: 7165.484
#   Best match (closest): 10367 (distance: 2889.581)
#   Worst match (farthest): 10996 (distance: 10278.177)
#
# shape4:
#   Total drawings: 895
#   Mean distance from original: 6809.838
#   Best match (closest): 7637 (distance: 2798.157)
#   Worst match (farthest): 10879 (distance: 8919.910)
#
# shape6:
#   Total drawings: 889
#   Mean distance from original: 6746.418
#   Best match (closest): 10308 (distance: 3337.622)
#   Worst match (farthest): 10090 (distance: 8796.106)
#
# shape7:
#   Total drawings: 893
#   Mean distance from original: 1491.864
#   Best match (closest): 10729 (distance: 72.664)
#   Worst match (farthest): 10706 (distance: 6196.660)
#
# shape2:
#   Total drawings: 900
#   Mean distance from original: 8129.395
#   Best match (closest): 11024 (distance: 1884.322)
#   Worst match (farthest): 10653 (distance: 14262.520)
#
# shape16:
#   Total drawings: 896
#   Mean distance from original: 6919.515
#   Best match (closest): 10815 (distance: 3800.943)
#   Worst match (farthest): 10021 (distance: 8277.591)
#
# shape17:
#   Total drawings: 893
#   Mean distance from original: 7125.450
#   Best match (closest): 7557 (distance: 4280.648)
#   Worst match (farthest): 10308 (distance: 8835.445)
#
# shape14:
#   Total drawings: 890
#   Mean distance from original: 2581.520
#   Best match (closest): 10149 (distance: 365.346)
#   Worst match (farthest): 11013 (distance: 11562.565)
#
# shape18:
#   Total drawings: 876
#   Mean distance from original: 4303.232
#   Best match (closest): 10522 (distance: 384.508)
#   Worst match (farthest): 10643 (distance: 11703.122)
#
# shape9:
#   Total drawings: 898
#   Mean distance from original: 8447.039
#   Best match (closest): 10005 (distance: 4406.916)
#   Worst match (farthest): 10952 (distance: 10042.571)
